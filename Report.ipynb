# %% [markdown]
# <font size="5">**Credit Card Cancellation Prediction**</font>
#
# <font size="4">by Jakub Kuciński and Karol Kuczmarz</font>

# %% [markdown]
# # Dataset
#
# Dataset contatins information about credit card customers. There is some information about card usage and card user. The aim is to find cancelling customers.
#
# Dataset contatins a few categorical features with missing values.

# %%
customers
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %% [markdown]
# Data imputation was performed via KNN.

# %%
# KNN data imputation
data_imputed
# Out:
#        CLIENTNUM  Customer_Age  Dependent_count Education_Level  \
# 0      768805383            45                3     High School
# 1      818770008            49                5        Graduate
# 2      713982108            51                3        Graduate
# 3      769911858            40                4     High School
# 4      709106358            40                3      Uneducated
# ...          ...           ...              ...             ...
# 10122  772366833            50                2        Graduate
# 10123  710638233            41                2        Graduate
# 10124  716506083            44                1     High School
# 10125  717406983            30                2        Graduate
# 10126  714337233            43                2        Graduate
#
#       Marital_Status  Income_Category  Card_Category  Months_on_book  \
# 0            Married               70              0              39
# ...

# %% [markdown]
# The distribution of cancelling and remaining customers is imbalanced. This caused need for artificial class rebalancing (oversampling, undersampling, SMOTE).

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Models

# %% [markdown]
# ## Classification models for 2d spaces
#
# Most promising variables found in EDA: Total_Trans_Amt and Total_Amt_Chng_Q4_Q1
#
# At first we visualized the dependencies between features in dataset and observed two promising variables.
#
# Then there are selected best or interesting results on different datasets and using various balancing methods.

# %% [markdown]
# ### Decision tree with oversampling

# %%
print(balanced_accuracy_score(y_test, y_pred), data_tree.score(X_test, y_test))
plt.show()
# Out:
# 0.7627090620031797 0.8767772511848341
# <img src="data:image/png;base64,..." width="336">
# <img src="data:image/png;base64,..." width="540">
# <img src="data:image/png;base64,..." width="538.4">
# <img src="data:image/png;base64,..." width="533.6">

# %% [markdown]
# ## Classification models for multidimensional spaces without class balancing

# %% [markdown]
# ### XGBoost

# %%
# with imputed data and dummy variables
temp_df = data_imputed_dummy

print("Score:", data_tree.score(X_test, y_test), "\nBalanced recall:", balanced_accuracy_score(y_test, y_pred))
plot_confusion_matrix(data_tree, X_test, y_test)
# Out:
# Score: 0.9687993680884676
# Balanced recall: 0.9287717878306114
# <img src="data:image/png;base64,..." width="378.1818099849482">

# %% [markdown]
# ## Classification models for multidimensional spaces with oversampling

# %% [markdown]
# ### Logistic Regression

# %%
# With imputed data and dummy variables without first
temp_df = data_dummies_without_first

print("Score:", model.score(X_test, y_test), "\nBalanced recall:", balanced_accuracy_score(y_test, y_pred))
plot_confusion_matrix(model, X_test, y_test)
# Out:
# Score: 0.8353080568720379
# Balanced recall: 0.8194461627402805
# <img src="data:image/png;base64,..." width="367.27271931230547">

# %%
# Logistic Regression on most important variables
# Indexes ['Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1']
plt.show()
# Out:
# Theta: [ 5.26041216e-04 -1.19559640e-01 -3.02763136e+00] const: [6.65354318]
# <img src="data:image/png;base64,..." width="827.2727093420742">

# %% [markdown]
# ### XGBoost

# %%
# with imputed data and dummy variables
temp_df = data_imputed_dummy

print("Score:", model.score(X_test, y_test), "\nBalanced recall:", balanced_accuracy_score(y_test, y_pred))
plot_confusion_matrix(model, X_test, y_test)
# Out:
# Score: 0.9715639810426541
# Balanced recall: 0.9522694030929325
# <img src="data:image/png;base64,..." width="404.54544577716814">

# %% [markdown]
# ## Classification models for multidimensional spaces with undersampling

# %% [markdown]
# ### XGBoost

# %%
# with imputed data and dummy variables
temp_df = data_imputed_dummy

print("Score:", data_tree.score(X_test, y_test), "\nBalanced recall:", balanced_accuracy_score(y_test, y_pred))
plot_confusion_matrix(data_tree, X_test, y_test)
# Out:
# Score: 0.945882659034734
# Balanced recall: 0.9528714528714528
# <img src="data:image/png;base64,..." width="355.45453775027585">

# %% [markdown]
# ## Classification models for multidimensional spaces with SMOTE

# %% [markdown]
# ### XGBoost

# %%
# without imputed data
temp_df = data.copy()

print("Score:", data_tree.score(X_test, y_test), "\nBalanced recall:", balanced_accuracy_score(y_test, y_pred))
plot_confusion_matrix(data_tree, X_test, y_test)
# Out:
# Score: 0.9695892575039494
# Balanced recall: 0.9510929325046972
# <img src="data:image/png;base64,..." width="384.54544621065645">

# %% [markdown]
# ## Cross-Validation error testing and feature importances
#
# Testing stratified cross-validation on XGBoost and different sampling methods. The results are the average of validations on particular folds.

# %% [markdown]
# ### XGBoost with oversampling

# %%
# with imputed data and dummies
temp_df = data_imputed_dummy.drop(columns=['Credit_Limit'])

print("Score:", score, "\nBalanced recall:", balance, "\nRecall for 0 class:", recalls[0], 
      "\nRecall for 1 class:", recalls[1])
# Out:
# Score: 0.9734370224123433
# Balanced recall: 0.9491369402881492
# Recall for 0 class: 0.9849411764705882
# Recall for 1 class: 0.9133327041057102

# %% [markdown]
# ### XGBoost with undersampling

# %%
# with dummies and missing values
temp_df = data_dummies.drop(columns=['Credit_Limit'])

print("Score:", score, "\nBalanced recall:", balance, "\nRecall for 0 class:", recalls[0], 
      "\nRecall for 1 class:", recalls[1])
# Out:
# Score: 0.9488560291076358
# Balanced recall: 0.9568398936161371
# Recall for 0 class: 0.9480997966706886
# Recall for 1 class: 0.9655799905615856

# %% [markdown]
# ### XGBoost with SMOTE

# %%
# with raw data
temp_df = data.drop(columns=['Credit_Limit'])

print("Score:", score, "\nBalanced recall:", balance, "\nRecall for 0 class:", recalls[0], 
      "\nRecall for 1 class:", recalls[1])
# Out:
# Score: 0.9685989787088832
# Balanced recall: 0.9507342253560225
# Recall for 0 class: 0.9770588235294116
# Recall for 1 class: 0.9244096271826333

# %% [markdown]
# # Visualization for 3 most important features:
# Total_Trans_Amt,Total_Trans_Ct, Total_Amt_Chng_Q4_Q1

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Wrapper
#
# Using `SequentialFeatureSelector` we plotted how model preformance depends on number of the most important features.

# %% [markdown]
# ## Undersampling with forward iteration

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## Oversampling with forward iteration

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="704.5454392748434">

# %% [markdown]
# ## Oversampling with backward iteration

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# # Summary
#
# Undersampling helps with finding resigning clients but causes loss in overall score.
# Data imputation slightly improved performance on oversampling.
# Selecting only a few (ca. 5) features produces arguably satisfying results.
# It turns out that card usage data is key but not sufficient piece of information. Adding variables like `Customer_Age` betters results.
